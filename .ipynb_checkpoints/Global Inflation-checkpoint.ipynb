# %%
import pandas as pd

file_data = pd.read_csv("./Resources/Final_Global Dataset of Inflation.csv", encoding="latin1")
file_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 country code                     inflation_type  \
# 0               0           0          ABW  Headline Consumer Price Inflation
# 1               1           2          AGO  Headline Consumer Price Inflation
# 2               2           3          ALB  Headline Consumer Price Inflation
# 3               3           4          ARE  Headline Consumer Price Inflation
# 4               4           5          ARG  Headline Consumer Price Inflation
# ..            ...         ...          ...                                ...
# 422           422         546          VEN      Food Consumer Price Inflation
# 423           423         548          VNM      Food Consumer Price Inflation
# 424           424         552          ZAF      Food Consumer Price Inflation
# 425           425         553          ZMB      Food Consumer Price Inflation
# 426           426         554          ZWE      Food Consumer Price Inflation
#
# ...

# %%
file_data = file_data.rename(columns = {"2005":"year_2005","2006":"year_2006","2007":"year_2007","2008":"year_2008","2009":"year_2009","2010":"year_2010","2011":"year_2011","2012":"year_2012","2013":"year_2013","2014":"year_2014","2015":"year_2015","2016":"year_2016","2017":"year_2017","2018":"year_2018","2019":"year_2019","2020":"year_2020","2021":"year_2021","2022":"year_2022" })
file_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 country code                     inflation_type  \
# 0               0           0          ABW  Headline Consumer Price Inflation
# 1               1           2          AGO  Headline Consumer Price Inflation
# 2               2           3          ALB  Headline Consumer Price Inflation
# 3               3           4          ARE  Headline Consumer Price Inflation
# 4               4           5          ARG  Headline Consumer Price Inflation
# ..            ...         ...          ...                                ...
# 422           422         546          VEN      Food Consumer Price Inflation
# 423           423         548          VNM      Food Consumer Price Inflation
# 424           424         552          ZAF      Food Consumer Price Inflation
# 425           425         553          ZMB      Food Consumer Price Inflation
# 426           426         554          ZWE      Food Consumer Price Inflation
#
# ...

# %%
file_data
# Out:
#      Unnamed: 0.1  Unnamed: 0 country code                     inflation_type  \
# 0               0           0          ABW  Headline Consumer Price Inflation
# 1               1           2          AGO  Headline Consumer Price Inflation
# 2               2           3          ALB  Headline Consumer Price Inflation
# 3               3           4          ARE  Headline Consumer Price Inflation
# 4               4           5          ARG  Headline Consumer Price Inflation
# ..            ...         ...          ...                                ...
# 422           422         546          VEN      Food Consumer Price Inflation
# 423           423         548          VNM      Food Consumer Price Inflation
# 424           424         552          ZAF      Food Consumer Price Inflation
# 425           425         553          ZMB      Food Consumer Price Inflation
# 426           426         554          ZWE      Food Consumer Price Inflation
#
# ...

# %%
file_data.to_csv('Official_Global Dataset of Inflation.csv')

# %%
file_data = pd.read_csv("./Output/Official_Global Dataset of Inflation.csv", encoding="latin1")
file_data
# Out:
#     country code                     inflation_type               country  \
# 0            ABW  Headline Consumer Price Inflation                 Aruba
# 1            AGO  Headline Consumer Price Inflation                Angola
# 2            ALB  Headline Consumer Price Inflation               Albania
# 3            ARE  Headline Consumer Price Inflation  United Arab Emirates
# 4            ARG  Headline Consumer Price Inflation             Argentina
# ..           ...                                ...                   ...
# 422          VEN      Food Consumer Price Inflation         Venezuela, RB
# 423          VNM      Food Consumer Price Inflation               Vietnam
# 424          ZAF      Food Consumer Price Inflation          South Africa
# 425          ZMB      Food Consumer Price Inflation                Zambia
# 426          ZWE      Food Consumer Price Inflation              Zimbabwe
#
#      year_2005  year_2006  year_2007  year_2008  year_2009  year_2010  \
# ...

# %%
# !pip install psycopg2

# %%
from sqlalchemy import create_engine

# %%
from config import username, password, hostname, port, db


# username = "postgres"
# password = "2d9c92d9c9"
# hostname = "localhost"
# port = "5432"
# db = "project_3"



engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{hostname}:{port}/{db}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19788\2289950681.py in <module>
# ----> 1 from config import username, password, hostname, port, db
#       2
#       3
#       4 # username = "postgres"
#       5 # password = "2d9c92d9c9"
#
# ImportError: cannot import name 'username' from 'config' (C:\Users\lopri\All Things Class Related\Gloabl Inflation\config.py)
