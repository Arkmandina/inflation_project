# %%
import pandas as pd

# %%
file_data = pd.read_csv("./Resources/Global Dataset of Inflation.csv", encoding="latin1")

# %%
file_data
# Out:
#     Country Code  IMF Country Code               Country Indicator Type  \
# 0            ABW             314.0                 Aruba      Inflation
# 1            AFG             512.0           Afghanistan      Inflation
# 2            AGO             614.0                Angola      Inflation
# 3            ALB             914.0               Albania      Inflation
# 4            ARE             466.0  United Arab Emirates      Inflation
# ..           ...               ...                   ...            ...
# 778          VEN             299.0         Venezuela, RB      Inflation
# 779          VNM             582.0               Vietnam      Inflation
# 780          XKX             967.0                Kosovo      Inflation
# 781          ZAF             199.0          South Africa      Inflation
# 782          ZMB             754.0                Zambia      Inflation
#
#                            Series Name   1970   1971   1972   1973   1974  \
# ...

# %%
file_data = file_data.loc[file_data["Series Name"] == "Headline Consumer Price Inflation"]
file_data
# Out:
#     Country Code  IMF Country Code                   Country Indicator Type  \
# 0            ABW             314.0                     Aruba      Inflation
# 1            AFG             512.0               Afghanistan      Inflation
# 2            AGO             614.0                    Angola      Inflation
# 3            ALB             914.0                   Albania      Inflation
# 4            ARE             466.0      United Arab Emirates      Inflation
# ..           ...               ...                       ...            ...
# 198          NCL             687.0             New Caledonia      Inflation
# 199          NIU             570.0                      Niue      Inflation
# 200          SHN             654.0              Saint Helena      Inflation
# 201          TLS             537.0               Timor-Leste      Inflation
# 202          TCA             796.0  Turks and Caicos Islands      Inflation
#
# ...

# %%
file_data = file_data.rename(columns = {"Country Code": "country_code", "Country" : "country", "Series Name" : "inflation_type","2005":"year_2005","2006":"year_2006","2007":"year_2007","2008":"year_2008","2009":"year_2009","2010":"year_2010","2011":"year_2011","2012":"year_2012","2013":"year_2013","2014":"year_2014","2015":"year_2015","2016":"year_2016","2017":"year_2017","2018":"year_2018","2019":"year_2019","2020":"year_2020","2021":"year_2021","2022":"year_2022" })
file_data
# Out:
#     country_code  IMF Country Code                   country Indicator Type  \
# 0            ABW             314.0                     Aruba      Inflation
# 1            AFG             512.0               Afghanistan      Inflation
# 2            AGO             614.0                    Angola      Inflation
# 3            ALB             914.0                   Albania      Inflation
# 4            ARE             466.0      United Arab Emirates      Inflation
# ..           ...               ...                       ...            ...
# 198          NCL             687.0             New Caledonia      Inflation
# 199          NIU             570.0                      Niue      Inflation
# 200          SHN             654.0              Saint Helena      Inflation
# 201          TLS             537.0               Timor-Leste      Inflation
# 202          TCA             796.0  Turks and Caicos Islands      Inflation
#
# ...

# %%
file_data = file_data[["country_code","country", "inflation_type", "year_2005","year_2006","year_2007","year_2008","year_2009","year_2010","year_2011","year_2012","year_2013","year_2014","year_2015","year_2016","year_2017","year_2018","year_2019","year_2020","year_2021","year_2022"]]
file_data
# Out:
#     country_code                   country                     inflation_type  \
# 0            ABW                     Aruba  Headline Consumer Price Inflation
# 1            AFG               Afghanistan  Headline Consumer Price Inflation
# 2            AGO                    Angola  Headline Consumer Price Inflation
# 3            ALB                   Albania  Headline Consumer Price Inflation
# 4            ARE      United Arab Emirates  Headline Consumer Price Inflation
# ..           ...                       ...                                ...
# 198          NCL             New Caledonia  Headline Consumer Price Inflation
# 199          NIU                      Niue  Headline Consumer Price Inflation
# 200          SHN              Saint Helena  Headline Consumer Price Inflation
# 201          TLS               Timor-Leste  Headline Consumer Price Inflation
# 202          TCA  Turks and Caicos Islands  Headline Consumer Price Inflation
#
# ...

# %%
file_data = file_data.dropna()
file_data
# Out:
#     country_code               country                     inflation_type  \
# 0            ABW                 Aruba  Headline Consumer Price Inflation
# 2            AGO                Angola  Headline Consumer Price Inflation
# 3            ALB               Albania  Headline Consumer Price Inflation
# 4            ARE  United Arab Emirates  Headline Consumer Price Inflation
# 5            ARG             Argentina  Headline Consumer Price Inflation
# ..           ...                   ...                                ...
# 188          WSM                 Samoa  Headline Consumer Price Inflation
# 189          YEM           Yemen, Rep.  Headline Consumer Price Inflation
# 190          ZAF          South Africa  Headline Consumer Price Inflation
# 191          ZMB                Zambia  Headline Consumer Price Inflation
# 192          ZWE              Zimbabwe  Headline Consumer Price Inflation
#
#      year_2005  year_2006  year_2007  year_2008  year_2009  year_2010  \
# ...

# %%
file_data.to_csv("./Output/Global Dataset of Inflation.csv")

# %%
from sqlalchemy import create_engine
from config import username, password, hostname, port, db

# %%
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{hostname}:{port}/{db}')

# %%
file_data.to_sql('inflation_db', con=engine, if_exists='replace', index=False)
# Out:
# 188
